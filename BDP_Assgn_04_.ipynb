# %%
# Install Java
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null

# Install PySpark
# !pip install pyspark
# Out:
# Collecting pyspark
#   Downloading pyspark-3.5.1.tar.gz (317.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.0/317.0 MB 4.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.5.1-py2.py3-none-any.whl size=317488493 sha256=559aaf0ce9f6e72cace141dbbbe37b50102cfc33d3403f6749f02e89b1d62a9e
#   Stored in directory: /root/.cache/pip/wheels/80/1d/60/2c256ed38dddce2fdd93be545214a63e02fbd8d74fb0b7f3a6
# Successfully built pyspark
# Installing collected packages: pyspark
# Successfully installed pyspark-3.5.1

# %%
from pyspark.sql import SparkSession
import numpy as np

# Create a SparkSession
spark = SparkSession.builder \
    .appName("RDD Task 1") \
    .getOrCreate()

# Task 1: Generate 100 random numbers in range 0 to 10 using numpy
np.random.seed(10)
random_numbers = np.random.randint(0, 11, 100)
print(random_numbers)

# Create RDD using the parallelize function
rdd = spark.sparkContext.parallelize(random_numbers)

# Task 1: Calculate the frequency of each number (0 - 10)
frequency = rdd.map(lambda x: (x, 1)).reduceByKey(lambda a, b: a + b)

# Print the frequency of each number
print("Frequency of each number (0 - 10):")
for num, freq in frequency.collect():
    print(f"Number {num}: {freq} times")

# Stop the SparkSession
spark.stop()
# Out:
# [ 9  4  0  1  9  0  1 10  8  9  0 10  8  6  4  3  0  4  6  8 10  1  8  4
#   1  3  6  5  3  9  6  9  1  9  4  2  6  7  8 10  8  9  2  0  6  7  8  1
#   7  1  4 10  0  8  5  4  7  8  8  2  6  2  8  8  6  6  5 10  6  0  0  6
#   9  1  8 10  9  1  2  8  9  9  5  0  2  7  3  0  4  2  0  3  3  1  2  5
#   9  0 10  1]
# Frequency of each number (0 - 10):
# Number 4: 8 times
# Number 0: 12 times
# Number 10: 8 times
# Number 8: 14 times
# Number 6: 11 times
# Number 2: 8 times
# Number 9: 12 times
# Number 1: 11 times
# Number 3: 6 times
# Number 5: 5 times
# Number 7: 5 times

# %%
# Create a SparkSession
spark = SparkSession.builder \
    .appName("RDD Task 2") \
    .getOrCreate()

# %%
# Load the text8 dataset
text_rdd = spark.sparkContext.textFile(r"/content/text8")

# Split each line into words and flatten the result
words_rdd = text_rdd.flatMap(lambda line: line.split())

# Map each word to a tuple (word, 1) for counting
word_count_rdd = words_rdd.map(lambda word: (word, 1))

# Reduce by key to get the count of each word
word_frequencies = word_count_rdd.reduceByKey(lambda a, b: a + b)

words_with_a = word_frequencies.filter(lambda x: 'a' in x[0])

# Print the frequencies of words containing the letter 'a'
print("Frequencies of words containing the letter 'a':")
for word, freq in words_with_a.collect():
    print(f"Word: {word}, Frequency: {freq}")

# Stop the SparkSession
spark.stop()
# Out:
# Streaming output truncated to the last 5000 lines.
# Word: srimad, Frequency: 1
# Word: jagannath, Frequency: 1
# Word: chinmayananda, Frequency: 1
# Word: kashinath, Frequency: 1
# Word: nirmalananda, Frequency: 2
# Word: tapasyananda, Frequency: 1
# Word: baladeva, Frequency: 1
# Word: vidyabhusana, Frequency: 1
# Word: kisari, Frequency: 1
# Word: ganguly, Frequency: 2
# Word: maharshi, Frequency: 2
# Word: ramana, Frequency: 1
# Word: eknath, Frequency: 1
# Word: kavya, Frequency: 1
# Word: madhuri, Frequency: 1
# Word: saral, Frequency: 1
# Word: alongwith, Frequency: 1
# Word: shaggy, Frequency: 3
# Word: squealing, Frequency: 2
# Word: primatologist, Frequency: 3
# Word: unaccountable, Frequency: 3
# Word: hoaxed, Frequency: 4
# Word: sesqac, Frequency: 1
# Word: wakemap, Frequency: 1
# Word: facemasks, Frequency: 1
# Word: nisga, Frequency: 1
# Word: barbes, Frequency: 1
# Word: anthropolgist, Frequency: 1
# Word: macphee, Frequency: 1
# Word: samish, Frequency: 1
# Word: klallam, Frequency: 1
# Word: farenbach, Frequency: 1
# Word: hoaxer, Frequency: 1
# Word: opposable, Frequency: 1
# Word: primatologists, Frequency: 2
# Word: engrave, Frequency: 1
# Word: dysplasia, Frequency: 3
# Word: daris, Frequency: 2
# Word: coltman, Frequency: 1
# Word: daegling, Frequency: 4
# Word: sarmiento, Frequency: 1
# Word: markotic, Frequency: 3
# Word: neanderthal, Frequency: 4
# Word: corroborative, Frequency: 1
# Word: blacki, Frequency: 5
# Word: quadrupedal, Frequency: 1
# Word: sivapithecus, Frequency: 2
# Word: strasenburg, Frequency: 1
# Word: laments, Frequency: 2
# Word: dearth, Frequency: 1
# Word: wasson, Frequency: 2
# Word: manlike, Frequency: 2
# Word: willapa, Frequency: 1
# Word: ghani, Frequency: 1
# Word: othman, Frequency: 1
# Word: kokanee, Frequency: 1
# Word: fakelore, Frequency: 1
# Word: wanton, Frequency: 1
# Word: ostman, Frequency: 1
# Word: coumbia, Frequency: 1
# Word: almas, Frequency: 1
# Word: bayanov, Frequency: 1
# Word: carelton, Frequency: 1
# Word: guttilla, Frequency: 1
# Word: sasquach, Frequency: 1
# Word: noticas, Frequency: 1
# Word: nutka, Frequency: 1
# Word: sprage, Frequency: 1
# Word: bigfootrussia, Frequency: 1
# Word: kal, Frequency: 2
# Word: artie, Frequency: 1
# Word: harrigan, Frequency: 1
# Word: musicaladers, Frequency: 1
# Word: pleasants, Frequency: 3
# Word: golfballs, Frequency: 1
# Word: leilani, Frequency: 1
# Word: ascap, Frequency: 3
# Word: ampex, Frequency: 10
# Word: magnetophone, Frequency: 2
# Word: poniatoff, Frequency: 1
# Word: magnecord, Frequency: 2
# Word: tasha, Frequency: 1
# Word: baritones, Frequency: 1
# Word: dardanella, Frequency: 1
# Word: snapshots, Frequency: 6
# Word: paleface, Frequency: 1
# Word: cinerama, Frequency: 1
# Word: bregman, Frequency: 1
# Word: satchmo, Frequency: 1
# Word: technolgical, Frequency: 1
# Word: spokanites, Frequency: 1
# Word: bamako, Frequency: 5
# Word: ratifications, Frequency: 1
# Word: clapp, Frequency: 1
# Word: mahshav, Frequency: 2
# Word: mahlah, Frequency: 1
# Word: maskil, Frequency: 1
# Word: sansanah, Frequency: 1
# Word: krakauer, Frequency: 1
# Word: timesharing, Frequency: 3
# Word: darsimco, Frequency: 1
# Word: imsai, Frequency: 1
# Word: basica, Frequency: 2
# Word: mystringarray, Frequency: 1
# Word: username, Frequency: 3
# Word: numstars, Frequency: 2
# Word: ucase, Frequency: 1
# Word: grandiloquence, Frequency: 1
# Word: kosmokrator, Frequency: 1
# Word: pseudorepublican, Frequency: 1
# Word: iovianus, Frequency: 1
# Word: valentinianus, Frequency: 1
# Word: pulcheria, Frequency: 2
# Word: valerius, Frequency: 1
# Word: iustinianus, Frequency: 1
# Word: exarch, Frequency: 2
# Word: bardanes, Frequency: 1
# Word: artemios, Frequency: 1
# Word: argyrus, Frequency: 1
# Word: paphlagonian, Frequency: 1
# Word: monomachus, Frequency: 1
# Word: bigamously, Frequency: 1
# Word: garrotte, Frequency: 1
# Word: trapezountas, Frequency: 1
# Word: palaeologid, Frequency: 2
# Word: dragatses, Frequency: 1
# Word: constantinopolitanus, Frequency: 1
# Word: protectorates, Frequency: 1
# Word: handover, Frequency: 3
# Word: naturalisation, Frequency: 15
# Word: adopters, Frequency: 2
# Word: applicants, Frequency: 6
# Word: renunciations, Frequency: 1
# Word: mackensen, Frequency: 1
# Word: bismark, Frequency: 1
# Word: encapsulates, Frequency: 1
# Word: interbase, Frequency: 6
# Word: objectpal, Frequency: 1
# Word: caliberrm, Frequency: 2
# Word: legadero, Frequency: 1
# Word: jdatastore, Frequency: 1
# Word: modula, Frequency: 2
# Word: actualization, Frequency: 1
# Word: machinist, Frequency: 1
# Word: appraisal, Frequency: 3
# Word: weatherproof, Frequency: 1
# Word: miniaturization, Frequency: 3
# Word: unobtainable, Frequency: 2
# Word: walkup, Frequency: 1
# Word: gadfly, Frequency: 1
# Word: pezzati, Frequency: 1
# Word: detracts, Frequency: 2
# Word: misleads, Frequency: 1
# Word: brenneman, Frequency: 1
# Word: fearnley, Frequency: 1
# Word: pasting, Frequency: 1
# Word: cheapening, Frequency: 1
# Word: blackhat, Frequency: 1
# Word: masquerades, Frequency: 1
# Word: maasai, Frequency: 1
# Word: beltzak, Frequency: 1
# Word: codebreakers, Frequency: 4
# Word: stableyard, Frequency: 1
# Word: chicksands, Frequency: 1
# Word: beaumanor, Frequency: 1
# Word: commandeered, Frequency: 1
# Word: sebag, Frequency: 1
# Word: beda, Frequency: 1
# Word: wearmouth, Frequency: 4
# Word: jarrow, Frequency: 4
# Word: autem, Frequency: 1
# Word: sententiam, Frequency: 1
# Word: animae, Frequency: 1
# Word: admonebat, Frequency: 1
# Word: snottora, Frequency: 1
# Word: earf, Frequency: 1
# Word: hap, Frequency: 1
# Word: opland, Frequency: 4
# Word: mohawks, Frequency: 1
# Word: flavorings, Frequency: 2
# Word: boba, Frequency: 6
# Word: teas, Frequency: 1
# Word: naicha, Frequency: 1
# Word: sago, Frequency: 2
# Word: putonghua, Frequency: 1
# Word: ovaltine, Frequency: 1
# Word: strawberry, Frequency: 7
# Word: tallard, Frequency: 1
# Word: creasy, Frequency: 3
# Word: ramillies, Frequency: 3
# Word: plauger, Frequency: 2
# Word: bootstrapping, Frequency: 27
# Word: backend, Frequency: 2
# Word: ironclads, Frequency: 2
# Word: dreadnoughts, Frequency: 28
# Word: galleasses, Frequency: 1
# Word: paixhans, Frequency: 4
# Word: redoutable, Frequency: 3
# Word: sharpness, Frequency: 4
# Word: barbette, Frequency: 1
# Word: planking, Frequency: 1
# Word: dreadnought, Frequency: 42
# Word: freeboard, Frequency: 1
# Word: mains, Frequency: 2
# Word: kearsarge, Frequency: 1
# Word: practicability, Frequency: 1
# Word: unaffordable, Frequency: 1
# Word: squander, Frequency: 1
# Word: calibres, Frequency: 2
# Word: breathtakingly, Frequency: 1
# Word: surpasssed, Frequency: 1
# Word: musashi, Frequency: 4
# Word: outmatch, Frequency: 1
# Word: battlewagons, Frequency: 2
# Word: petropavlovsk, Frequency: 2
# Word: tallboy, Frequency: 1
# Word: nishimura, Frequency: 1
# Word: yamashiro, Frequency: 1
# Word: surigao, Frequency: 1
# Word: kurita, Frequency: 1
# Word: nagato, Frequency: 1
# Word: ostfriesland, Frequency: 1
# Word: rivadavia, Frequency: 1
# Word: latorre, Frequency: 1
# Word: yavuz, Frequency: 2
# Word: lehman, Frequency: 2
# Word: tlams, Frequency: 1
# Word: krasina, Frequency: 1
# Word: hazegray, Frequency: 1
# Word: heimdallr, Frequency: 1
# Word: tann, Frequency: 4
# Word: maass, Frequency: 1
# Word: stubstantial, Frequency: 1
# Word: akagi, Frequency: 1
# Word: panzerschiffe, Frequency: 1
# Word: spearfish, Frequency: 1
# Word: savo, Frequency: 1
# Word: alaskas, Frequency: 1
# Word: planed, Frequency: 1
# Word: thyazholyi, Frequency: 1
# Word: kalinin, Frequency: 1
# Word: ushakov, Frequency: 1
# Word: faired, Frequency: 1
# Word: interchangable, Frequency: 1
# Word: alpuget, Frequency: 3
# Word: medicare, Frequency: 4
# Word: balder, Frequency: 33
# Word: baldr, Frequency: 4
# Word: baldur, Frequency: 1
# Word: nanna, Frequency: 5
# Word: draumar, Frequency: 1
# Word: nonthreatening, Frequency: 1
# Word: unanswerable, Frequency: 1
# Word: giantess, Frequency: 4
# Word: frigga, Frequency: 1
# Word: balderus, Frequency: 5
# Word: textar, Frequency: 1
# Word: gurra, Frequency: 1
# Word: meginhandrita, Frequency: 1
# Word: freya, Frequency: 6
# Word: alfrik, Frequency: 1
# Word: dvalin, Frequency: 1
# Word: alberich, Frequency: 1
# Word: brosingamen, Frequency: 1
# Word: hama, Frequency: 1
# Word: teardrop, Frequency: 2
# Word: barometric, Frequency: 2
# Word: karol, Frequency: 1
# Word: dimensionale, Frequency: 1
# Word: issledowatelskii, Frequency: 1
# Word: matematiki, Frequency: 1
# Word: mechaniki, Frequency: 1
# Word: sirleaf, Frequency: 1
# Word: chalice, Frequency: 3
# Word: bragi, Frequency: 60
# Word: bragr, Frequency: 6
# Word: skaldship, Frequency: 2
# Word: periphrase, Frequency: 1
# Word: graven, Frequency: 2
# Word: skaldic, Frequency: 3
# Word: kvasir, Frequency: 1
# Word: skald, Frequency: 1
# Word: boddason, Frequency: 7
# Word: bragis, Frequency: 1
# Word: mabinogi, Frequency: 1
# Word: brage, Frequency: 1
# Word: bragga, Frequency: 2
# Word: brag, Frequency: 2
# Word: bragget, Frequency: 1
# Word: brugga, Frequency: 3
# Word: hamdir, Frequency: 1
# Word: bragnings, Frequency: 2
# Word: bragning, Frequency: 1
# Word: hundingsbana, Frequency: 1
# Word: dermanland, Frequency: 2
# Word: gassendi, Frequency: 1
# Word: barometers, Frequency: 1
# Word: touchant, Frequency: 2
# Word: ached, Frequency: 1
# Word: wearisome, Frequency: 1
# Word: hypochondria, Frequency: 1
# Word: laxity, Frequency: 1
# Word: montalte, Frequency: 1
# Word: casuistical, Frequency: 1
# Word: lacrymalis, Frequency: 1
# Word: armorial, Frequency: 1
# Word: mesnard, Frequency: 2
# Word: rahilly, Frequency: 1
# Word: breatann, Frequency: 1
# Word: lexically, Frequency: 2
# Word: periphrastic, Frequency: 2
# Word: shaha, Frequency: 1
# Word: filppula, Frequency: 1
# Word: communards, Frequency: 2
# Word: gayest, Frequency: 2
# Word: unpolitical, Frequency: 1
# Word: wishart, Frequency: 1
# Word: headliners, Frequency: 1
# Word: prolifically, Frequency: 1
# Word: phonogram, Frequency: 1
# Word: yotta, Frequency: 1
# Word: megabits, Frequency: 1
# Word: unformatted, Frequency: 1
# Word: lanchau, Frequency: 1
# Word: addie, Frequency: 1
# Word: headshot, Frequency: 1
# Word: solvable, Frequency: 2
# Word: impagliazzo, Frequency: 2
# Word: nisan, Frequency: 2
# Word: kabanets, Frequency: 1
# Word: factoring, Frequency: 4
# Word: pspace, Frequency: 3
# Word: brainfuck, Frequency: 69
# Word: brainf, Frequency: 4
# Word: initialises, Frequency: 1
# Word: iteratively, Frequency: 2
# Word: panu, Frequency: 2
# Word: braintwist, Frequency: 1
# Word: thrat, Frequency: 1
# Word: pbrain, Frequency: 1
# Word: nanopond, Frequency: 2
# Word: evolvable, Frequency: 1
# Word: cosmac, Frequency: 1
# Word: faase, Frequency: 1
# Word: keymaker, Frequency: 1
# Word: awib, Frequency: 1
# Word: lavina, Frequency: 1
# Word: ocala, Frequency: 1
# Word: shiras, Frequency: 1
# Word: settignano, Frequency: 1
# Word: baccio, Frequency: 1
# Word: bandinelli, Frequency: 3
# Word: vignola, Frequency: 1
# Word: toleda, Frequency: 1
# Word: signoria, Frequency: 1
# Word: bartolommeo, Frequency: 2
# Word: bargello, Frequency: 3
# Word: parnassus, Frequency: 1
# Word: battiferri, Frequency: 1
# Word: latifundia, Frequency: 1
# Word: williamsthe, Frequency: 1
# Word: marprelate, Frequency: 1
# Word: prelacy, Frequency: 1
# Word: thyateira, Frequency: 1
# Word: auxiliaries, Frequency: 5
# Word: coadjutors, Frequency: 1
# Word: antimension, Frequency: 1
# Word: ordinations, Frequency: 4
# Word: ntanda, Frequency: 1
# Word: diacons, Frequency: 1
# Word: bordelais, Frequency: 1
# Word: cabernet, Frequency: 2
# Word: sauvignon, Frequency: 2
# Word: malbec, Frequency: 1
# Word: carmenere, Frequency: 1
# Word: muscadelle, Frequency: 1
# Word: chateau, Frequency: 2
# Word: sauternes, Frequency: 1
# Word: universitaire, Frequency: 2
# Word: talence, Frequency: 1
# Word: urbanism, Frequency: 1
# Word: neuralgic, Frequency: 1
# Word: cazaux, Frequency: 1
# Word: bmibaby, Frequency: 1
# Word: bastia, Frequency: 1
# Word: portugalia, Frequency: 1
# Word: tunisair, Frequency: 1
# Word: mitterrand, Frequency: 1
# Word: anouilh, Frequency: 1
# Word: damita, Frequency: 1
# Word: mauriac, Frequency: 1
# Word: canel, Frequency: 1
# Word: frankton, Frequency: 1
# Word: exoskeletal, Frequency: 1
# Word: carapaces, Frequency: 1
# Word: trabecular, Frequency: 1
# Word: diaphysis, Frequency: 1
# Word: medullar, Frequency: 3
# Word: mineralised, Frequency: 1
# Word: phosphatase, Frequency: 3
# Word: lacuna, Frequency: 1
# Word: mechano, Frequency: 1
# Word: multinucleated, Frequency: 1
# Word: lacunae, Frequency: 2
# Word: unmineralized, Frequency: 1
# Word: tropocollagen, Frequency: 1
# Word: osteocalcin, Frequency: 1
# Word: ossification, Frequency: 7
# Word: diaphyses, Frequency: 2
# Word: epiphyseal, Frequency: 1
# Word: bretanwealda, Frequency: 1
# Word: bretwaldas, Frequency: 3
# Word: raedwald, Frequency: 1
# Word: lapidge, Frequency: 1
# Word: nostradamus, Frequency: 1
# Word: pedemontanus, Frequency: 1
# Word: naphthenate, Frequency: 1
# Word: chlorinated, Frequency: 3
# Word: derivates, Frequency: 3
# Word: disproportionation, Frequency: 2
# Word: phosphorfructokinase, Frequency: 1
# Word: benzoates, Frequency: 1
# Word: terephthalic, Frequency: 3
# Word: benzoat, Frequency: 1
# Word: plasticizer, Frequency: 1
# Word: cyclohexanol, Frequency: 1
# Word: chemicalland, Frequency: 1
# Word: unnormalised, Frequency: 1
# Word: danner, Frequency: 17
# Word: playbill, Frequency: 1
# Word: thiooxidans, Frequency: 1
# Word: catalyse, Frequency: 1
# Word: adsorbing, Frequency: 1
# Word: aspergillus, Frequency: 1
# Word: bactech, Frequency: 1
# Word: brandl, Frequency: 1
# Word: crashpad, Frequency: 1
# Word: pba, Frequency: 7
# Word: yaba, Frequency: 1
# Word: bpaa, Frequency: 6
# Word: scoreability, Frequency: 1
# Word: vaporized, Frequency: 1
# Word: kilopascals, Frequency: 1
# Word: isotropically, Frequency: 1
# Word: gravitationally, Frequency: 3
# Word: baryonic, Frequency: 10
# Word: recessional, Frequency: 3
# Word: anisotropies, Frequency: 3
# Word: resolvable, Frequency: 1
# Word: unaccounted, Frequency: 3
# Word: oscillatory, Frequency: 1
# Word: bhagavata, Frequency: 1
# Word: christianson, Frequency: 1
# Word: ivanchik, Frequency: 1
# Word: navabi, Frequency: 1
# Word: feuerbacher, Frequency: 1
# Word: croissant, Frequency: 1
# Word: radiale, Frequency: 1
# Word: extragalactiques, Frequency: 1
# Word: extragalactic, Frequency: 2
# Word: pisma, Frequency: 1
# Word: paulaner, Frequency: 6
# Word: salvator, Frequency: 4
# Word: maibock, Frequency: 10
# Word: maibocks, Frequency: 3
# Word: ayinger, Frequency: 4
# Word: schlenklera, Frequency: 1
# Word: liberally, Frequency: 2
# Word: flavorful, Frequency: 1
# Word: andechser, Frequency: 1
# Word: celebrator, Frequency: 1
# Word: triumphator, Frequency: 1
# Word: optimator, Frequency: 1
# Word: kulmbacher, Frequency: 1
# Word: bantus, Frequency: 3
# Word: saharans, Frequency: 1
# Word: swazi, Frequency: 3
# Word: kwazulu, Frequency: 3
# Word: shaka, Frequency: 3
# Word: khumalos, Frequency: 1
# Word: matabele, Frequency: 1
# Word: mzilikazi, Frequency: 1
# Word: mpande, Frequency: 2
# Word: kraal, Frequency: 1
# Word: headmen, Frequency: 1
# Word: vhavenda, Frequency: 2
# Word: shangana, Frequency: 3
# Word: amazulu, Frequency: 1
# Word: amaxhosa, Frequency: 2
# Word: basotho, Frequency: 1
# Word: patrilinear, Frequency: 2
# Word: schapera, Frequency: 1
# Word: cameroonian, Frequency: 5
# Word: amekisoma, Frequency: 1
# Word: pluralizing, Frequency: 2
# Word: watoto, Frequency: 2
# Word: vitabu, Frequency: 1
# Word: wamevisoma, Frequency: 1
# Word: shona, Frequency: 3
# Word: luganda, Frequency: 1
# Word: runyankole, Frequency: 1
# Word: rukiga, Frequency: 1
# Word: kihaya, Frequency: 1
# Word: kinyarwanda, Frequency: 1
# Word: tshiluba, Frequency: 1
# Word: siswati, Frequency: 1
# Word: ngumba, Frequency: 1
# Word: kiswahili, Frequency: 2
# Word: lengola, Frequency: 1
# Word: nyanga, Frequency: 2
# Word: bila, Frequency: 3
# Word: bera, Frequency: 1
# Word: ndaka, Frequency: 1
# Word: nyali, Frequency: 1
# Word: vanuma, Frequency: 1
# Word: zimba, Frequency: 1
# Word: kahe, Frequency: 1
# Word: rusa, Frequency: 1
# Word: malakote, Frequency: 1
# Word: giryama, Frequency: 1
# Word: nyika, Frequency: 1
# Word: sagalia, Frequency: 1
# Word: kabwa, Frequency: 1
# Word: ikoma, Frequency: 1
# Word: nata, Frequency: 1
# Word: zanaki, Frequency: 1
# Word: chuka, Frequency: 1
# Word: sumbwa, Frequency: 1
# Word: langi, Frequency: 1
# Word: nyaturu, Frequency: 1
# Word: kaonde, Frequency: 1
# Word: nkoya, Frequency: 1
# Word: hemba, Frequency: 1
# Word: kanyok, Frequency: 1
# Word: mantengo, Frequency: 1
# Word: tumbuka, Frequency: 1
# Word: kunda, Frequency: 1
# Word: mwera, Frequency: 1
# Word: makonde, Frequency: 1
# Word: machinga, Frequency: 1
# Word: matumbi, Frequency: 1
# Word: makhuwa, Frequency: 5
# Word: shirima, Frequency: 1
# Word: marrevone, Frequency: 1
# Word: nyaneka, Frequency: 1
# Word: kwanyama, Frequency: 1
# Word: ngandyera, Frequency: 1
# Word: mbalanhu, Frequency: 1
# Word: dema, Frequency: 1
# Word: manyika, Frequency: 1
# Word: ndau, Frequency: 1
# Word: tawara, Frequency: 1
# Word: inhambane, Frequency: 1
# Word: tswa, Frequency: 1
# Word: swati, Frequency: 1
# Word: birwa, Frequency: 1
# Word: gbati, Frequency: 1
# Word: isanzu, Frequency: 1
# Word: kari, Frequency: 2
# Word: ngbinda, Frequency: 1
# Word: marimba, Frequency: 1
# Word: simba, Frequency: 1
# Word: sprachen, Frequency: 2
# Word: maho, Frequency: 1
# Word: pascale, Frequency: 1
# Word: banto, Frequency: 1
# Word: maniacky, Frequency: 1
# Word: bomarc, Frequency: 13
# Word: bomarcs, Frequency: 4
# Word: urariquira, Frequency: 2
# Word: brainstorm, Frequency: 1
# Word: brainstormin, Frequency: 1
# Word: slashdotted, Frequency: 1
# Word: localhost, Frequency: 1
# Word: realgrouchy, Frequency: 2
# Word: inforamtion, Frequency: 1
# Word: ifaqeer, Frequency: 3
# Word: beland, Frequency: 1
# Word: cyberlaw, Frequency: 1
# Word: informationsphere, Frequency: 1
# Word: econsultant, Frequency: 1
# Word: penpals, Frequency: 1
# Word: fasi, Frequency: 1
# Word: daumier, Frequency: 2
# Word: cta, Frequency: 1
# Word: laidlaw, Frequency: 1
# Word: motorcoach, Frequency: 1
# Word: unconstitutionality, Frequency: 1
# Word: barraclou, Frequency: 1
# Word: gamelan, Frequency: 2
# Word: denpasar, Frequency: 2
# Word: sanur, Frequency: 1
# Word: seminyak, Frequency: 1
# Word: ngurah, Frequency: 1
# Word: pasut, Frequency: 3
# Word: sungai, Frequency: 1
# Word: segara, Frequency: 1
# Word: klatingdukuh, Frequency: 1
# Word: tanah, Frequency: 1
# Word: ikat, Frequency: 1
# Word: balidwipa, Frequency: 1
# Word: blanjong, Frequency: 1
# Word: kesari, Frequency: 1
# Word: walidwipa, Frequency: 1
# Word: majapahit, Frequency: 1
# Word: baris, Frequency: 4
# Word: barong, Frequency: 1
# Word: covarrubias, Frequency: 1
# Word: renarrative, Frequency: 9
# Word: morphohologically, Frequency: 1
# Word: glagolitic, Frequency: 3
# Word: palatalizes, Frequency: 1
# Word: coalescence, Frequency: 3
# Word: naj, Frequency: 1
# Word: jutija, Frequency: 1
# Word: jadzia, Frequency: 1
# Word: allophonic, Frequency: 1
# Word: alternations, Frequency: 1
# Word: palatum, Frequency: 3
# Word: mutables, Frequency: 1
# Word: syntactically, Frequency: 1
# Word: immutables, Frequency: 1
# Word: phraseological, Frequency: 1
# Word: prepositional, Frequency: 1
# Word: participles, Frequency: 5
# Word: predicatively, Frequency: 1
# Word: zdrav, Frequency: 1
# Word: bavo, Frequency: 1
# Word: blagodary, Frequency: 1
# Word: angl, Frequency: 2
# Word: lgarski, Frequency: 1
# Word: dipyramid, Frequency: 11
# Word: enneagonal, Frequency: 2
# Word: apexes, Frequency: 1
# Word: alliteratively, Frequency: 1
# Word: newquay, Frequency: 1
# Word: pawprints, Frequency: 1
# Word: maximizes, Frequency: 2
# Word: uda, Frequency: 1
# Word: arkadii, Frequency: 1
# Word: manipulable, Frequency: 1
# Word: davide, Frequency: 1
# Word: fabrice, Frequency: 1
# Word: valognes, Frequency: 1
# Word: serais, Frequency: 1
# Word: classifier, Frequency: 1
# Word: ratliff, Frequency: 1
# Word: lida, Frequency: 1
# Word: colindale, Frequency: 3
# Word: cloakroom, Frequency: 1
# Word: thomason, Frequency: 3
# Word: apac, Frequency: 1
# Word: philatelic, Frequency: 1
# Word: digitizations, Frequency: 1
# Word: brunonians, Frequency: 1
# Word: coeducational, Frequency: 2
# Word: curricular, Frequency: 1
# Word: deans, Frequency: 1
# Word: tougaloo, Frequency: 1
# Word: philermenian, Frequency: 1
# Word: fraternities, Frequency: 3
# Word: carberry, Frequency: 3
# Word: snackbar, Frequency: 1
# Word: adventuresome, Frequency: 1
# Word: araby, Frequency: 1
# Word: braingate, Frequency: 1
# Word: fabrica, Frequency: 2
# Word: cataloger, Frequency: 1
# Word: brunoniana, Frequency: 2
# Word: haffenreffer, Frequency: 1
# Word: hypercard, Frequency: 2
# Word: tresillian, Frequency: 1
# Word: auntie, Frequency: 3
# Word: pearsall, Frequency: 2
# Word: kallen, Frequency: 2
# Word: penrhyndeudraeth, Frequency: 1
# Word: hegelianism, Frequency: 1
# Word: datum, Frequency: 1
# Word: extensionality, Frequency: 2
# Word: explication, Frequency: 1
# Word: strawson, Frequency: 3
# Word: verifiability, Frequency: 1
# Word: omphalos, Frequency: 1
# Word: yearned, Frequency: 1
# Word: battersea, Frequency: 1
# Word: overstate, Frequency: 3
# Word: conflate, Frequency: 1
# Word: companionate, Frequency: 1
# Word: alexandr, Frequency: 1
# Word: norgate, Frequency: 1
# Word: kasrils, Frequency: 1
# Word: matematica, Frequency: 1
# Word: evanston, Frequency: 1
# Word: inaugurate, Frequency: 1
# Word: planemad, Frequency: 2
# Word: mastermind, Frequency: 2
# Word: coattails, Frequency: 1
# Word: shanahan, Frequency: 1
# Word: announcers, Frequency: 4
# Word: mitarai, Frequency: 1
# Word: olfa, Frequency: 1
# Word: chalcolithic, Frequency: 1
# Word: natually, Frequency: 1
# Word: luristan, Frequency: 1
# Word: patina, Frequency: 1
# Word: luxembourgian, Frequency: 1
# Word: barnicle, Frequency: 2
# Word: grays, Frequency: 3
# Word: carrigan, Frequency: 1
# Word: tantrum, Frequency: 1
# Word: acquiesced, Frequency: 2
# Word: balking, Frequency: 1
# Word: calmness, Frequency: 1
# Word: anemic, Frequency: 1
# Word: shawkey, Frequency: 1
# Word: embarassed, Frequency: 1
# Word: kenesaw, Frequency: 1
# Word: bellyache, Frequency: 2
# Word: flailed, Frequency: 1
# Word: uncontrollably, Frequency: 2
# Word: napping, Frequency: 2
# Word: gaffe, Frequency: 2
# Word: ruthian, Frequency: 1
# Word: profanities, Frequency: 1
# Word: disappoint, Frequency: 1
# Word: examiners, Frequency: 1
# Word: overloaded, Frequency: 3
# Word: carbuncle, Frequency: 1
# Word: navin, Frequency: 3
# Word: hoopla, Frequency: 1
# Word: ballooned, Frequency: 1
# Word: cachexia, Frequency: 1
# Word: roseanne, Frequency: 2
# Word: populuar, Frequency: 1
# Word: reidenbach, Frequency: 1
# Word: shafter, Frequency: 2
# Word: linkable, Frequency: 1
# Word: deckhands, Frequency: 1
# Word: towboat, Frequency: 3
# Word: barica, Frequency: 1
# Word: camouflauge, Frequency: 1
# Word: kesselschlacht, Frequency: 3
# Word: platoons, Frequency: 3
# Word: batallions, Frequency: 1
# Word: afire, Frequency: 2
# Word: reconaissance, Frequency: 1
# Word: codenames, Frequency: 2
# Word: hamel, Frequency: 1
# Word: ancre, Frequency: 1
# Word: valvrojenski, Frequency: 1
# Word: giugliano, Frequency: 1
# Word: ethnobotany, Frequency: 2
# Word: herbals, Frequency: 1
# Word: apsb, Frequency: 1
# Word: schlaffsucht, Frequency: 1
# Word: anthracis, Frequency: 5
# Word: diptera, Frequency: 1
# Word: kurstaki, Frequency: 1
# Word: bacillaceae, Frequency: 1
# Word: bacteriostasis, Frequency: 1
# Word: bacteriostats, Frequency: 2
# Word: bactericide, Frequency: 2
# Word: joujouka, Frequency: 4
# Word: radiophonic, Frequency: 1
# Word: dreamachine, Frequency: 1
# Word: hommages, Frequency: 1
# Word: calmette, Frequency: 3
# Word: vaccinated, Frequency: 1
# Word: intradermally, Frequency: 1
# Word: lamm, Frequency: 2
# Word: sarcoid, Frequency: 1
# Word: heaf, Frequency: 1
# Word: scardino, Frequency: 1
# Word: buzzards, Frequency: 2
# Word: plumages, Frequency: 1
# Word: plaintive, Frequency: 2
# Word: cathartes, Frequency: 1
# Word: oganessian, Frequency: 1
# Word: apsidium, Frequency: 1
# Word: duracell, Frequency: 2
# Word: camcorder, Frequency: 1
# Word: rechargers, Frequency: 1
# Word: wristwatches, Frequency: 1
# Word: ninacl, Frequency: 1
# Word: nanicl, Frequency: 1
# Word: populatity, Frequency: 1
# Word: aaaa, Frequency: 1
# Word: wafer, Frequency: 1
# Word: radioshack, Frequency: 1
# Word: nonrechargeable, Frequency: 1
# Word: urania, Frequency: 1
# Word: canis, Frequency: 1
# Word: asterion, Frequency: 1
# Word: venatici, Frequency: 1
# Word: profaners, Frequency: 1
# Word: draco, Frequency: 2
# Word: alkalurops, Frequency: 1
# Word: observantine, Frequency: 1
# Word: capuchins, Frequency: 3
# Word: colonna, Frequency: 2
# Word: carafa, Frequency: 1
# Word: articulus, Frequency: 1
# Word: stantis, Frequency: 1
# Word: cadentis, Frequency: 1
# Word: dialoge, Frequency: 1
# Word: assailing, Frequency: 1
# Word: benrath, Frequency: 2
# Word: bicarburet, Frequency: 1
# Word: tetravalent, Frequency: 1
# Word: crystallographer, Frequency: 1
# Word: aromatics, Frequency: 3
# Word: alkylbenzenes, Frequency: 1
# Word: phenanthrene, Frequency: 1
# Word: pyrazine, Frequency: 1
# Word: hydrodealkylation, Frequency: 3
# Word: dealkylation, Frequency: 1
# Word: degreasing, Frequency: 1
# Word: sanka, Frequency: 1
# Word: phaseout, Frequency: 1
# Word: acylium, Frequency: 1
# Word: carbocations, Frequency: 1
# Word: sulfonation, Frequency: 1
# Word: aml, Frequency: 1
# Word: carcinogenesis, Frequency: 1
# Word: traum, Frequency: 1
# Word: bassoon, Frequency: 91
# Word: fagotto, Frequency: 1
# Word: bassoonist, Frequency: 18
# Word: dulcians, Frequency: 1
# Word: shawms, Frequency: 1
# Word: curtall, Frequency: 1
# Word: coenraad, Frequency: 1
# Word: almenr, Frequency: 6
# Word: caecilia, Frequency: 1
# Word: guntram, Frequency: 1
# Word: serveral, Frequency: 1
# Word: stamitz, Frequency: 1
# Word: dukas, Frequency: 1
# Word: rhapsodie, Frequency: 1
# Word: fantastique, Frequency: 1
# Word: arundo, Frequency: 1
# Word: premade, Frequency: 1
# Word: bajon, Frequency: 1
# Word: flautist, Frequency: 1
# Word: rabinowitz, Frequency: 1
# Word: bassoonsists, Frequency: 1
# Word: jancourt, Frequency: 1
# Word: kovar, Frequency: 1
# Word: schoenbach, Frequency: 1
# Word: allard, Frequency: 1
# Word: leclair, Frequency: 1
# Word: langwill, Frequency: 1
# Word: lyndesay, Frequency: 1
# Word: birchard, Frequency: 1
# Word: stratotanker, Frequency: 1
# Word: tapao, Frequency: 1
# Word: turbofan, Frequency: 4
# Word: ailerons, Frequency: 1
# Word: hydraulically, Frequency: 1
# Word: crabbed, Frequency: 1
# Word: strangelove, Frequency: 2
# Word: himat, Frequency: 1
# Word: hatches, Frequency: 6
# Word: bipedally, Frequency: 2
# Word: aborting, Frequency: 1
# Word: straighten, Frequency: 1
# Word: hamstring, Frequency: 1
# Word: wading, Frequency: 2
# Word: gymnastic, Frequency: 2
# Word: handstand, Frequency: 1
# Word: astrophied, Frequency: 1
# Word: treads, Frequency: 2
# Word: asimo, Frequency: 2
# Word: ocaml, Frequency: 2
# Word: impedances, Frequency: 2
# Word: alternator, Frequency: 2
# Word: outage, Frequency: 1
# Word: maturities, Frequency: 2
# Word: interpolation, Frequency: 4
# Word: gianforte, Frequency: 1
# Word: bootstrappers, Frequency: 1
# Word: admissability, Frequency: 1
# Word: bourjaily, Frequency: 1
# Word: latgalian, Frequency: 2
# Word: galindan, Frequency: 1
# Word: yotvingian, Frequency: 1
# Word: semigallian, Frequency: 1
# Word: martynas, Frequency: 1
# Word: pashka, Frequency: 1
# Word: lituanus, Frequency: 1
# Word: microarrays, Frequency: 7
# Word: sirna, Frequency: 1
# Word: cdna, Frequency: 1
# Word: microarray, Frequency: 4
# Word: polyploidization, Frequency: 1
# Word: parse, Frequency: 1
# Word: biojava, Frequency: 2
# Word: vigyaancd, Frequency: 1
# Word: taverna, Frequency: 2
# Word: qsar, Frequency: 1
# Word: curation, Frequency: 1
# Word: baxevanis, Frequency: 1
# Word: claverie, Frequency: 1
# Word: notredame, Frequency: 1
# Word: donaggio, Frequency: 1
# Word: leguizamo, Frequency: 2
# Word: romanek, Frequency: 1
# Word: enraptured, Frequency: 1
# Word: gravitated, Frequency: 2
# Word: salability, Frequency: 1
# Word: carlito, Frequency: 3
# Word: depalma, Frequency: 3
# Word: dopplegangers, Frequency: 1
# Word: fatales, Frequency: 1
# Word: wotans, Frequency: 1
# Word: newarkers, Frequency: 1
# Word: airpower, Frequency: 1
# Word: chromate, Frequency: 1
# Word: maimie, Frequency: 1
# Word: empennage, Frequency: 2
# Word: strafing, Frequency: 2
# Word: usaaf, Frequency: 2
# Word: apabhramsa, Frequency: 1
# Word: avahattha, Frequency: 1
# Word: assamese, Frequency: 9
# Word: maghadan, Frequency: 1
# Word: chittagonian, Frequency: 3
# Word: chakma, Frequency: 3
# Word: bankim, Frequency: 2
# Word: shantipur, Frequency: 1
# Word: bahe, Frequency: 1
# Word: kharia, Frequency: 1
# Word: rajbangshi, Frequency: 1
# Word: manipuri, Frequency: 1
# Word: mayek, Frequency: 1
# Word: intonational, Frequency: 1
# Word: monosyllables, Frequency: 1
# Word: snan, Frequency: 2
# Word: glash, Frequency: 2
# Word: raivar, Frequency: 1
# Word: skar, Frequency: 1
# Word: animacy, Frequency: 1
# Word: chhatro, Frequency: 6
# Word: palato, Frequency: 1
# Word: debuccalization, Frequency: 1
# Word: apico, Frequency: 1
# Word: slamalikum, Frequency: 1
# Word: daoat, Frequency: 2
# Word: mehman, Frequency: 1
# Word: doa, Frequency: 1
# Word: khoda, Frequency: 1
# Word: khala, Frequency: 1
# Word: ngka, Frequency: 1
# Word: shathe, Frequency: 1
# Word: charyageeti, Frequency: 1
# Word: rabindrasangeets, Frequency: 1
# Word: gitanjali, Frequency: 1
# Word: madhusudan, Frequency: 2
# Word: dutta, Frequency: 1
# Word: tarashankar, Frequency: 1
# Word: bandopadhay, Frequency: 1
# Word: basu, Frequency: 1
# Word: choitanyo, Frequency: 1
# Word: advaitist, Frequency: 1
# Word: kathamrita, Frequency: 1
# Word: atleast, Frequency: 1
# Word: bishad, Frequency: 1
# Word: karbala, Frequency: 1
# Word: mosharraf, Frequency: 1
# Word: naxalite, Frequency: 1
# Word: shamsur, Frequency: 1
# Word: sufia, Frequency: 1
# Word: azizul, Frequency: 1
# Word: akhtaruzzaman, Frequency: 1
# Word: ilias, Frequency: 1
# Word: gangopadhyay, Frequency: 1
# Word: shankha, Frequency: 1
# Word: mahasweta, Frequency: 1
# Word: idioma, Frequency: 1
# Word: bengalla, Frequency: 1
# Word: partes, Frequency: 1
# Word: manoel, Frequency: 1
# Word: assumpcam, Frequency: 2
# Word: bhawal, Frequency: 1
# Word: brassey, Frequency: 3
# Word: halhed, Frequency: 1
# Word: bhasha, Frequency: 3
# Word: transliterator, Frequency: 1
# Word: samsad, Frequency: 1
# Word: marshalled, Frequency: 1
# Word: acclimatised, Frequency: 1
# Word: rheinstadion, Frequency: 1
# Word: fulham, Frequency: 4
# Word: commentating, Frequency: 1
# Word: parlane, Frequency: 1
# Word: nasl, Frequency: 1
# Word: goalkeeping, Frequency: 1
# Word: blanchflower, Frequency: 2
# Word: galvanise, Frequency: 1
# Word: arrowed, Frequency: 1
# Word: benfica, Frequency: 1
# Word: testimonial, Frequency: 1
# Word: makepeace, Frequency: 1
# Word: pervades, Frequency: 1
# Word: raconteur, Frequency: 1
# Word: paisiello, Frequency: 1
# Word: tympani, Frequency: 1
# Word: khaki, Frequency: 4
# Word: candidatures, Frequency: 1
# Word: unease, Frequency: 1
# Word: leyland, Frequency: 2
# Word: mandelson, Frequency: 6
# Word: unilateralist, Frequency: 1
# Word: thatcherite, Frequency: 3
# Word: taskforces, Frequency: 1
# Word: sainsbury, Frequency: 4
# Word: specialisms, Frequency: 1
# Word: miliband, Frequency: 1
# Word: wandsworth, Frequency: 1
# Word: spinwatch, Frequency: 1
# Word: scaffold, Frequency: 2
# Word: organelle, Frequency: 3
# Word: appratus, Frequency: 1
# Word: thermoplasma, Frequency: 1
# Word: borrelia, Frequency: 1
# Word: extrachromosomal, Frequency: 1
# Word: eukaryote, Frequency: 1
# Word: catabolism, Frequency: 1
# Word: trna, Frequency: 3
# Word: parasitism, Frequency: 2
# Word: microscopical, Frequency: 2
# Word: spontanea, Frequency: 1
# Word: cellula, Frequency: 2
# Word: plasmolysis, Frequency: 1
# Word: apon, Frequency: 1
# Word: tablier, Frequency: 1
# Word: pissarro, Frequency: 1
# Word: cassatt, Frequency: 1
# Word: kickstarted, Frequency: 1
# Word: goizueta, Frequency: 1
# Word: retailer, Frequency: 2
# Word: marlboro, Frequency: 1
# Word: jarlsberg, Frequency: 1
# Word: ikea, Frequency: 1
# Word: antiglobalization, Frequency: 1
# Word: pantone, Frequency: 1
# Word: basingstoke, Frequency: 2
# Word: brandmarker, Frequency: 1
# Word: brandingmarketing, Frequency: 1
# Word: satsified, Frequency: 1
# Word: easiness, Frequency: 2
# Word: mccay, Frequency: 1
# Word: erica, Frequency: 1
# Word: arce, Frequency: 1
# Word: lorelai, Frequency: 1
# Word: janna, Frequency: 1
# Word: jhumpa, Frequency: 1
# Word: lahiri, Frequency: 1
# Word: brashares, Frequency: 1
# Word: danticat, Frequency: 1
# Word: atoosa, Frequency: 1
# Word: cassinese, Frequency: 1
# Word: bernardines, Frequency: 1
# Word: trappists, Frequency: 1
# Word: marmion, Frequency: 1
# Word: stanbrook, Frequency: 1
# Word: cadfael, Frequency: 3
# Word: confoederatio, Frequency: 1
# Word: lani, Frequency: 3
# Word: bayezid, Frequency: 29
# Word: pygmachia, Frequency: 1
# Word: himantes, Frequency: 1
# Word: headbutting, Frequency: 2
# Word: resultantly, Frequency: 1
# Word: angling, Frequency: 1
# Word: occasioning, Frequency: 1
# Word: featherweight, Frequency: 3
# Word: scorecards, Frequency: 2
# Word: rickard, Frequency: 1
# Word: simona, Frequency: 1
# Word: wba, Frequency: 2
# Word: ribcage, Frequency: 1
# Word: brawling, Frequency: 1
# Word: mallin, Frequency: 1
# Word: santion, Frequency: 1
# Word: carnera, Frequency: 1
# Word: ezzard, Frequency: 1
# Word: heaveyweight, Frequency: 1
# Word: evander, Frequency: 3
# Word: hassim, Frequency: 1
# Word: monahan, Frequency: 1
# Word: trinadad, Frequency: 1
# Word: mayweather, Frequency: 2
# Word: kostya, Frequency: 1
# Word: jacan, Frequency: 1
# Word: canastota, Frequency: 3
# Word: bma, Frequency: 1
# Word: stanwyck, Frequency: 1
# Word: dunaway, Frequency: 1
# Word: rhames, Frequency: 1
# Word: parkwest, Frequency: 1
# Word: kidnappers, Frequency: 3
# Word: estimable, Frequency: 1
# Word: amusements, Frequency: 1
# Word: suraiyya, Frequency: 1
# Word: lawaaris, Frequency: 1
# Word: kya, Frequency: 2
# Word: tawaif, Frequency: 1
# Word: picturisations, Frequency: 1
# Word: kaha, Frequency: 1
# Word: gaadi, Frequency: 1
# Word: tumhaarey, Frequency: 1
# Word: maa, Frequency: 1
# Word: pairings, Frequency: 6
# Word: kaisey, Frequency: 1
# Word: maut, Frequency: 1
# Word: aayi, Frequency: 2
# Word: amours, Frequency: 1
# Word: clannish, Frequency: 1
# Word: kapoors, Frequency: 1
# Word: babita, Frequency: 1
# Word: karisma, Frequency: 1
# Word: ranbir, Frequency: 1
# Word: hema, Frequency: 1
# Word: malini, Frequency: 1
# Word: abhay, Frequency: 1
# Word: bachchans, Frequency: 1
# Word: rajesh, Frequency: 3
# Word: akshay, Frequency: 1
# Word: akshaye, Frequency: 1
# Word: nargis, Frequency: 1
# Word: hussains, Frequency: 1
# Word: malaika, Frequency: 1
# Word: shobhana, Frequency: 1
# Word: sashadhar, Frequency: 1
# Word: sharbani, Frequency: 1
# Word: tanuja, Frequency: 1
# Word: pataudis, Frequency: 1
# Word: sharmila, Frequency: 1
# Word: soha, Frequency: 1
# Word: hridayanath, Frequency: 1
# Word: iifa, Frequency: 1
# Word: apsara, Frequency: 1
# Word: harishchandra, Frequency: 2
# Word: bhatvadekar, Frequency: 1
# Word: phalke, Frequency: 1
# Word: escapist, Frequency: 1
# Word: melodramas, Frequency: 1
# Word: aapke, Frequency: 1
# Word: jayenge, Frequency: 1
# Word: chahta, Frequency: 2
# Word: tejaswini, Frequency: 1
# Word: kabir, Frequency: 1
# Word: ashish, Frequency: 1
# Word: giitaayan, Frequency: 1
# Word: geetmanjusha, Frequency: 1
# Word: barcelonettes, Frequency: 1
# Word: maisons, Frequency: 1
# Word: mexicaines, Frequency: 1
# Word: wayfarer, Frequency: 2
# Word: fathomed, Frequency: 1
# Word: consummation, Frequency: 1
# Word: intimations, Frequency: 1
# Word: azal, Frequency: 1
# Word: akk, Frequency: 2
# Word: adhereing, Frequency: 1
# Word: inundations, Frequency: 1
# Word: intercalary, Frequency: 1
# Word: bahaiyouth, Frequency: 1
# Word: shaykhism, Frequency: 1
# Word: orthographies, Frequency: 4
# Word: astrachan, Frequency: 3
# Word: burgundarholmr, Frequency: 1
# Word: godsaga, Frequency: 1
# Word: stjerna, Frequency: 2
# Word: gravefields, Frequency: 1
# Word: nerman, Frequency: 2
# Word: lkerwanderung, Frequency: 1
# Word: gundobad, Frequency: 24
# Word: gundahar, Frequency: 7
# Word: gundicar, Frequency: 2
# Word: lauter, Frequency: 21
# Word: nahe, Frequency: 1
# Word: borbetomagus, Frequency: 1
# Word: sapaudia, Frequency: 2
# Word: catalaunian, Frequency: 1
# Word: panegyr, Frequency: 1
# Word: avit, Frequency: 1
# Word: implicates, Frequency: 1
# Word: malalas, Frequency: 1
# Word: gundobada, Frequency: 4
# Word: clotilda, Frequency: 1
# Word: ribuaria, Frequency: 1
# Word: shanzer, Frequency: 3
# Word: ossiemanners, Frequency: 1
# Word: bastardization, Frequency: 2
# Word: bergans, Frequency: 1
# Word: norvegian, Frequency: 1
# Word: placename, Frequency: 1
# Word: candice, Frequency: 1
# Word: bundesautobahn, Frequency: 1
# Word: marysville, Frequency: 1
# Word: binarysearch, Frequency: 2
# Word: bsearch, Frequency: 1
# Word: kildea, Frequency: 1
# Word: curated, Frequency: 1
# Word: spermatozoon, Frequency: 1
# Word: abortifacients, Frequency: 4
# Word: beeswax, Frequency: 2
# Word: gynaecologist, Frequency: 1
# Word: blacksmiths, Frequency: 1
# Word: contraceptives, Frequency: 6
# Word: implanon, Frequency: 1
# Word: lactational, Frequency: 1
# Word: tubal, Frequency: 1
# Word: acceptations, Frequency: 1
# Word: onan, Frequency: 1
# Word: halakhah, Frequency: 3
# Word: halachic, Frequency: 1
# Word: tatman, Frequency: 1
# Word: anscombe, Frequency: 1
# Word: vlan, Frequency: 1
# Word: heavly, Frequency: 1
# Word: hammers, Frequency: 3
# Word: deadbeat, Frequency: 1
# Word: escapement, Frequency: 3
# Word: decimalisation, Frequency: 1
# Word: routemaster, Frequency: 1
# Word: drac, Frequency: 1
# Word: skyscrapernews, Frequency: 1
# Word: staggerwings, Frequency: 1
# Word: bonanza, Frequency: 8
# Word: debonair, Frequency: 1
# Word: blau, Frequency: 7
# Word: tsaritsyn, Frequency: 1
# Word: halder, Frequency: 2
# Word: vatutin, Frequency: 1
# Word: manstein, Frequency: 3
# Word: restabilize, Frequency: 1
# Word: abhorred, Frequency: 1
# Word: gumrak, Frequency: 1
# Word: sportpalast, Frequency: 1
# Word: anatolyevian, Frequency: 1
# Word: zelma, Frequency: 1
# Word: kobylyanskiy, Frequency: 1
# Word: annaud, Frequency: 1
# Word: tamo, Frequency: 1
# Word: shaolin, Frequency: 15
# Word: reverberating, Frequency: 1
# Word: chanted, Frequency: 2
# Word: exultation, Frequency: 2
# Word: tanlin, Frequency: 6
# Word: daisetz, Frequency: 1
# Word: teitaro, Frequency: 1
# Word: daoxuan, Frequency: 10
# Word: daoyu, Frequency: 4
# Word: taishou, Frequency: 1
# Word: patriach, Frequency: 2
# Word: sandal, Frequency: 2
# Word: tarim, Frequency: 1
# Word: lankavatara, Frequency: 5
# Word: yogacara, Frequency: 2
# Word: asanga, Frequency: 2
# Word: bodhidarma, Frequency: 1
# Word: eisai, Frequency: 1
# Word: taiping, Frequency: 1
# Word: daoist, Frequency: 2
# Word: tiantai, Frequency: 1
# Word: meditator, Frequency: 1
# Word: gabi, Frequency: 1
# Word: philosofical, Frequency: 1
# Word: guangxi, Frequency: 2
# Word: krai, Frequency: 1
# Word: kalmykia, Frequency: 1
# Word: ambedkar, Frequency: 1
# Word: buddhachat, Frequency: 1
# Word: dhammapada, Frequency: 1
# Word: urbandharma, Frequency: 1
# Word: vipassana, Frequency: 2
# Word: maha, Frequency: 1
# Word: satipatthana, Frequency: 1
# Word: tagcta, Frequency: 1
# Word: uagcua, Frequency: 1
# Word: nucleobase, Frequency: 1
# Word: testaverde, Frequency: 4
# Word: boulware, Frequency: 1
# Word: grbac, Frequency: 3
# Word: outgained, Frequency: 1
# Word: bouchat, Frequency: 5
# Word: faxed, Frequency: 1
# Word: moag, Frequency: 1
# Word: mackey, Frequency: 1
# Word: marchetti, Frequency: 1
# Word: hartwell, Frequency: 1
# Word: siragusa, Frequency: 1
# Word: fassel, Frequency: 1
# Word: spearhead, Frequency: 4
# Word: faeces, Frequency: 1
# Word: barclays, Frequency: 2
# Word: jyllands, Frequency: 1
# Word: paedophiles, Frequency: 1
# Word: beater, Frequency: 1
# Word: bashed, Frequency: 2
# Word: pakis, Frequency: 1
# Word: hasmukh, Frequency: 1
# Word: vishwa, Frequency: 1
# Word: canvassers, Frequency: 1
# Word: treacy, Frequency: 1
# Word: ayotolla, Frequency: 1
# Word: heartedly, Frequency: 1
# Word: millwall, Frequency: 2
# Word: barking, Frequency: 5
# Word: uaf, Frequency: 1
# Word: enunciating, Frequency: 1
# Word: luaf, Frequency: 1
# Word: gerrymandered, Frequency: 1
# Word: acknowleges, Frequency: 1
# Word: fracas, Frequency: 1
# Word: newspapper, Frequency: 1
# Word: batavii, Frequency: 5
# Word: batavi, Frequency: 1
# Word: batavians, Frequency: 7
# Word: waal, Frequency: 1
# Word: stela, Frequency: 1
# Word: bravest, Frequency: 1
# Word: medway, Frequency: 1
# Word: swam, Frequency: 4
# Word: capito, Frequency: 1
# Word: primae, Frequency: 2
# Word: batavorum, Frequency: 1
# Word: credobaptism, Frequency: 4
# Word: baptisands, Frequency: 1
# Word: rebaptizer, Frequency: 1
# Word: unbaptised, Frequency: 2
# Word: mandaeanism, Frequency: 1
# Word: aspersion, Frequency: 2
# Word: paedobaptism, Frequency: 3
# Word: ritually, Frequency: 2
# Word: inextinguishable, Frequency: 1
# Word: partakers, Frequency: 1
# Word: baptistry, Frequency: 1
# Word: cleanses, Frequency: 1
# Word: knowledgeably, Frequency: 1
# Word: unbaptized, Frequency: 2
# Word: calixte, Frequency: 1
# Word: catacomb, Frequency: 1
# Word: invalidation, Frequency: 1
# Word: officiant, Frequency: 1
# Word: layperson, Frequency: 2
# Word: rebaptize, Frequency: 1
# Word: regulative, Frequency: 1
# Word: amrit, Frequency: 5
# Word: sanchar, Frequency: 1
# Word: prays, Frequency: 3
# Word: schachtendoop, Frequency: 1
# Word: kallistos, Frequency: 1
# Word: diokleia, Frequency: 1
# Word: dispensationalist, Frequency: 1
# Word: underarm, Frequency: 1
# Word: granaglia, Frequency: 2
# Word: mondiale, Frequency: 2
# Word: quadrennial, Frequency: 1
# Word: boccia, Frequency: 1
# Word: grasso, Frequency: 1
# Word: slipmats, Frequency: 1
# Word: crossfader, Frequency: 1
# Word: fader, Frequency: 1
# Word: cerinthians, Frequency: 2
# Word: radkey, Frequency: 1
# Word: chagall, Frequency: 1
# Word: talalay, Frequency: 1
# Word: dardashti, Frequency: 1
# Word: rebaptised, Frequency: 1
# Word: beltaine, Frequency: 5
# Word: bealtuinn, Frequency: 1
# Word: bael, Frequency: 1
# Word: belisama, Frequency: 1
# Word: thaich, Frequency: 1
# Word: baos, Frequency: 1
# Word: baelos, Frequency: 1
# Word: lach, Frequency: 4
# Word: beolach, Frequency: 1
# Word: baile, Frequency: 1
# Word: calton, Frequency: 1
# Word: sabbat, Frequency: 1
# Word: wiccan, Frequency: 1
# Word: beantown, Frequency: 3
# Word: shawmut, Frequency: 2
# Word: wharves, Frequency: 1
# Word: charlestown, Frequency: 6
# Word: noreaster, Frequency: 1
# Word: takoradi, Frequency: 1
# Word: bayside, Frequency: 1
# Word: umass, Frequency: 1
# Word: prudential, Frequency: 1
# Word: vibrantly, Frequency: 1
# Word: banknorth, Frequency: 1
# Word: beanpot, Frequency: 1
# Word: braintree, Frequency: 1
# Word: quabbin, Frequency: 1
# Word: wachusett, Frequency: 1
# Word: nstar, Frequency: 1
# Word: keyspan, Frequency: 1
# Word: areaconnect, Frequency: 1
# Word: kadingirra, Frequency: 1
# Word: karanduniash, Frequency: 1
# Word: arakhtu, Frequency: 1
# Word: expiation, Frequency: 1
# Word: ziggurat, Frequency: 2
# Word: seleucia, Frequency: 1
# Word: babil, Frequency: 2
# Word: qasr, Frequency: 1
# Word: mujelliba, Frequency: 1
# Word: borsippa, Frequency: 1
# Word: ctesias, Frequency: 7
# Word: stades, Frequency: 5
# Word: jala, Frequency: 2
# Word: ephratah, Frequency: 1
# Word: encampments, Frequency: 2
# Word: hadid, Frequency: 2
# Word: benjamites, Frequency: 1
# Word: desolating, Frequency: 1
# Word: bava, Frequency: 2
# Word: slackness, Frequency: 1
# Word: wakeman, Frequency: 3
# Word: catchier, Frequency: 1
# Word: appice, Frequency: 7
# Word: squabbled, Frequency: 1
# Word: trapeze, Frequency: 2
# Word: instrumetnal, Frequency: 1
# Word: anselmo, Frequency: 1
# Word: saban, Frequency: 3
# Word: delamielleure, Frequency: 3
# Word: seahawks, Frequency: 3
# Word: polian, Frequency: 1
# Word: antowain, Frequency: 3
# Word: mcgahee, Frequency: 1
# Word: donahoe, Frequency: 2
# Word: abramoski, Frequency: 1
# Word: saimes, Frequency: 1
# Word: smerlas, Frequency: 1
# Word: darryl, Frequency: 4
# Word: talley, Frequency: 2
# Word: stationery, Frequency: 2
# Word: modrak, Frequency: 1
# Word: moratorium, Frequency: 2
# Word: untangle, Frequency: 1
# Word: kerasiotes, Frequency: 1
# Word: truckloads, Frequency: 1
# Word: hayyamim, Frequency: 1
# Word: paralipomenon, Frequency: 1
# Word: zerubbabel, Frequency: 2
# Word: tzaraas, Frequency: 1
# Word: hayamim, Frequency: 2
# Word: traversals, Frequency: 1
# Word: nodevalue, Frequency: 2
# Word: heapsort, Frequency: 1
# Word: mcmad, Frequency: 1
# Word: smarter, Frequency: 1
# Word: lapdog, Frequency: 1
# Word: warden, Frequency: 14
# Word: savident, Frequency: 1
# Word: elapses, Frequency: 1
# Word: squalid, Frequency: 1
# Word: abetted, Frequency: 1
# Word: grenadiers, Frequency: 2
# Word: awakes, Frequency: 2
# Word: apologises, Frequency: 1
# Word: shaven, Frequency: 3
# Word: scarlett, Frequency: 1
# Word: blackadders, Frequency: 1
# Word: parters, Frequency: 1
# Word: haig, Frequency: 1
# Word: lurkalot, Frequency: 2
# Word: cisalpine, Frequency: 1
# Word: maccius, Frequency: 2
# Word: rauraci, Frequency: 1
# Word: latobrigi, Frequency: 1
# Word: norican, Frequency: 1
# Word: noreia, Frequency: 1
# Word: magalus, Frequency: 1
# Word: captiva, Frequency: 1
# Word: mostellaria, Frequency: 1
# Word: kmacfarl, Frequency: 1
# Word: backgammon, Frequency: 46
# Word: tabula, Frequency: 6
# Word: backgammons, Frequency: 2
# Word: takhte, Frequency: 2
# Word: tavla, Frequency: 2
# Word: mahbusa, Frequency: 4
# Word: azerbaidjan, Frequency: 1
# Word: tavli, Frequency: 2
# Word: plakoto, Frequency: 2
# Word: fevga, Frequency: 2
# Word: longgammon, Frequency: 2
# Word: tesauro, Frequency: 1
# Word: nackgammon, Frequency: 1
# Word: acey, Frequency: 1
# Word: gadites, Frequency: 2
# Word: mitzvah, Frequency: 8
# Word: gibeath, Frequency: 1
# Word: haaraloth, Frequency: 1
# Word: zabdi, Frequency: 1
# Word: achan, Frequency: 3
# Word: achor, Frequency: 1
# Word: jarmuth, Frequency: 1
# Word: lachish, Frequency: 3
# Word: jasher, Frequency: 2
# Word: ajalon, Frequency: 1
# Word: jabin, Frequency: 5
# Word: hamstrings, Frequency: 1
# Word: interweaving, Frequency: 1
# Word: kiriath, Frequency: 2
# Word: achsah, Frequency: 2
# Word: timnah, Frequency: 1
# Word: faithfulness, Frequency: 2
# Word: habiru, Frequency: 1
# Word: amihai, Frequency: 1
# Word: archaelogy, Frequency: 1
# Word: mishael, Frequency: 1
# Word: belshazzar, Frequency: 14
# Word: burtchaell, Frequency: 1
# Word: madai, Frequency: 1
# Word: nabuna, Frequency: 1
# Word: extrabiblical, Frequency: 1
# Word: qprnab, Frequency: 1
# Word: transmogrified, Frequency: 1
# Word: nebuchadnez, Frequency: 1
# Word: homerica, Frequency: 1
# Word: hagiographa, Frequency: 1
# Word: verbiage, Frequency: 1
# Word: teiman, Frequency: 1
# Word: deuterocanoncial, Frequency: 1
# Word: walvoord, Frequency: 1
# Word: tyndale, Frequency: 3
# Word: batwoman, Frequency: 4
# Word: batmobile, Frequency: 10
# Word: batgirl, Frequency: 9
# Word: imitators, Frequency: 4
# Word: knightfall, Frequency: 3
# Word: escapology, Frequency: 1
# Word: thawed, Frequency: 1
# Word: catwoman, Frequency: 36
# Word: selina, Frequency: 17
# Word: aquaman, Frequency: 1
# Word: teamup, Frequency: 2
# Word: villainous, Frequency: 1
# Word: tacticians, Frequency: 1
# Word: barris, Frequency: 2
# Word: batarang, Frequency: 2
# Word: scanner, Frequency: 1
# Word: batarangs, Frequency: 1
# Word: gunman, Frequency: 1
# Word: batwing, Frequency: 1
# Word: scallops, Frequency: 1
# Word: villainesses, Frequency: 1
# Word: barrionuevo, Frequency: 1
# Word: wertham, Frequency: 4
# Word: tamer, Frequency: 1
# Word: bookrags, Frequency: 1
# Word: dimaggio, Frequency: 1
# Word: rainout, Frequency: 1
# Word: junkballer, Frequency: 1
# Word: schiraldi, Frequency: 1
# Word: yawkeys, Frequency: 1
# Word: yawkey, Frequency: 5
# Word: nomar, Frequency: 2
# Word: micromanage, Frequency: 1
# Word: beane, Frequency: 1
# Word: millar, Frequency: 4
# Word: disastrously, Frequency: 1
# Word: knucleballing, Frequency: 1
# Word: vasquez, Frequency: 1
# Word: suppan, Frequency: 1
# Word: graffanino, Frequency: 2
# Word: mota, Frequency: 2
# Word: paydirt, Frequency: 1
# Word: anheuser, Frequency: 15
# Word: alomar, Frequency: 2
# Word: davey, Frequency: 2
# Word: palmeiro, Frequency: 5
# Word: hargrove, Frequency: 2
# Word: mazzilli, Frequency: 4
# Word: javy, Frequency: 2
# Word: matos, Frequency: 2
# Word: newhan, Frequency: 1
# Word: latroy, Frequency: 1
# Word: baltimoreans, Frequency: 1
# Word: bedard, Frequency: 1
# Word: baysox, Frequency: 1
# Word: casserole, Frequency: 1
# Word: haggle, Frequency: 1
# Word: dandruff, Frequency: 1
# Word: saut, Frequency: 1
# Word: latrine, Frequency: 1
# Word: fricass, Frequency: 1
# Word: scratchit, Frequency: 1
# Word: avocado, Frequency: 1
# Word: underpants, Frequency: 2
# Word: bastarnae, Frequency: 7
# Word: mithridates, Frequency: 1
# Word: cancels, Frequency: 1
# Word: condensates, Frequency: 14
# Word: ultralow, Frequency: 1
# Word: sakurai, Frequency: 1
# Word: zizka, Frequency: 4
# Word: bohemians, Frequency: 4
# Word: rozmital, Frequency: 1
# Word: maiestas, Frequency: 1
# Word: rudolphina, Frequency: 1
# Word: haims, Frequency: 1
# Word: centralistic, Frequency: 1
# Word: reichsprotektorat, Frequency: 1
# Word: ceska, Frequency: 1
# Word: kralove, Frequency: 1
# Word: subcontracted, Frequency: 1
# Word: salz, Frequency: 1
# Word: sarkis, Frequency: 1
# Word: zarin, Frequency: 1
# Word: copycat, Frequency: 1
# Word: xtra, Frequency: 1
# Word: jacobsson, Frequency: 1
# Word: trafficrank, Frequency: 1
# Word: blaga, Frequency: 1
# Word: damazer, Frequency: 1
# Word: gloating, Frequency: 1
# Word: gaggle, Frequency: 1
# Word: subcarriers, Frequency: 1
# Word: simulcasting, Frequency: 2
# Word: bannister, Frequency: 4
# Word: smashie, Frequency: 1
# Word: playlisted, Frequency: 1
# Word: lamacq, Frequency: 2
# Word: rockumentary, Frequency: 2
# Word: mclelland, Frequency: 1
# Word: cabled, Frequency: 1
# Word: removals, Frequency: 1
# Word: baldric, Frequency: 2
# Word: wargame, Frequency: 2
# Word: mullard, Frequency: 1
# Word: sidways, Frequency: 1
# ...
# Word: ajedrez, Frequency: 1
# Word: zatrikion, Frequency: 1
# Word: alfinus, Frequency: 1
# Word: alfferza, Frequency: 1
# Word: anderssen, Frequency: 3
# Word: kasimdzhanov, Frequency: 1
# Word: shawshank, Frequency: 1
# Word: chessbase, Frequency: 2
# Word: playchess, Frequency: 1
# Word: instantchess, Frequency: 1
# Word: gameknot, Frequency: 1
# Word: highergames, Frequency: 1
# Word: stadacona, Frequency: 3
# Word: donnacona, Frequency: 1
# Word: anse, Frequency: 1
# Word: cumulatively, Frequency: 1
# Word: cincinnatians, Frequency: 1
# Word: hanwell, Frequency: 1
# Word: karno, Frequency: 3
# Word: sneaking, Frequency: 1
# Word: choreography, Frequency: 1
# Word: oona, Frequency: 3
# Word: vaud, Frequency: 1
# Word: caricaturist, Frequency: 1
# Word: floorwalker, Frequency: 1
# Word: pawnshop, Frequency: 1
# Word: purviance, Frequency: 1
# Word: kiera, Frequency: 1
# Word: classicmovies, Frequency: 1
# Word: starrie, Frequency: 1
# Word: steganography, Frequency: 4
# Word: cryptogram, Frequency: 1
# Word: polyalphabetic, Frequency: 5
# Word: cardan, Frequency: 1
# Word: hellman, Frequency: 4
# Word: adleman, Frequency: 1
# Word: cryptanalyst, Frequency: 5
# Word: zimmermann, Frequency: 1
# Word: platitudes, Frequency: 1
# Word: particularism, Frequency: 2
# Word: particularists, Frequency: 1
# Word: inculcation, Frequency: 1
# Word: provably, Frequency: 1
# Word: colorable, Frequency: 1
# Word: downplays, Frequency: 1
# Word: myanma, Frequency: 1
# Word: nationmaster, Frequency: 2
# Word: abkazia, Frequency: 1
# Word: cornwallflag, Frequency: 1
# Word: populationdata, Frequency: 1
# Word: kopenhagen, Frequency: 1
# Word: bjerregaard, Frequency: 1
# Word: asmus, Frequency: 1
# Word: kjeldgaard, Frequency: 1
# Word: labout, Frequency: 1
# Word: forkbeard, Frequency: 1
# Word: havn, Frequency: 1
# Word: trainlines, Frequency: 1
# Word: amager, Frequency: 2
# Word: landskrona, Frequency: 1
# Word: enghave, Frequency: 1
# Word: vestamager, Frequency: 1
# Word: plads, Frequency: 1
# Word: parken, Frequency: 1
# Word: cobras, Frequency: 1
# Word: christiansborg, Frequency: 2
# Word: amalienborg, Frequency: 1
# Word: arken, Frequency: 1
# Word: kastellet, Frequency: 1
# Word: brandes, Frequency: 1
# Word: jacobsen, Frequency: 1
# Word: aok, Frequency: 1
# Word: enumerative, Frequency: 7
# Word: matroid, Frequency: 3
# Word: extremal, Frequency: 7
# Word: combinatorialists, Frequency: 1
# Word: algebraization, Frequency: 1
# Word: calx, Frequency: 1
# Word: calcis, Frequency: 1
# Word: manjula, Frequency: 1
# Word: jyeshtadeva, Frequency: 1
# Word: newtoncalculus, Frequency: 1
# Word: hyperreal, Frequency: 1
# Word: loftsgaarden, Frequency: 1
# Word: spivak, Frequency: 1
# Word: stroyan, Frequency: 1
# Word: faraz, Frequency: 1
# Word: sangamagramma, Frequency: 1
# Word: transactive, Frequency: 1
# Word: intrapersonal, Frequency: 1
# Word: communcation, Frequency: 1
# Word: jakobson, Frequency: 1
# Word: communicare, Frequency: 1
# Word: smartmobbing, Frequency: 1
# Word: indiscrimination, Frequency: 1
# Word: semaphores, Frequency: 1
# Word: classicus, Frequency: 2
# Word: metacharatte, Frequency: 1
# Word: nomisma, Frequency: 1
# Word: humaniores, Frequency: 2
# Word: tartu, Frequency: 1
# Word: linguae, Frequency: 1
# Word: describable, Frequency: 1
# Word: astrochemistry, Frequency: 1
# Word: paramagnetic, Frequency: 1
# Word: biomacromolecules, Frequency: 1
# Word: alkemie, Frequency: 1
# Word: mashiach, Frequency: 1
# Word: messias, Frequency: 1
# Word: essenian, Frequency: 1
# Word: rosicrucian, Frequency: 3
# Word: passionless, Frequency: 1
# Word: cheapens, Frequency: 1
# Word: nunataks, Frequency: 1
# Word: batholites, Frequency: 1
# Word: torngat, Frequency: 1
# Word: fuca, Frequency: 2
# Word: coola, Frequency: 1
# Word: saskatchewann, Frequency: 1
# Word: ofpopulation, Frequency: 1
# Word: eckankar, Frequency: 1
# Word: layton, Frequency: 1
# Word: asdb, Frequency: 1
# Word: minurca, Frequency: 1
# Word: untaet, Frequency: 1
# Word: rideau, Frequency: 2
# Word: encana, Frequency: 1
# Word: barrick, Frequency: 1
# Word: regionalism, Frequency: 1
# Word: multifaceted, Frequency: 1
# Word: skytrain, Frequency: 1
# Word: welland, Frequency: 1
# Word: cancour, Frequency: 1
# Word: paralled, Frequency: 1
# Word: proceduralism, Frequency: 1
# Word: unanimity, Frequency: 1
# Word: simonianism, Frequency: 1
# Word: montanism, Frequency: 1
# Word: swedenborgian, Frequency: 1
# Word: mithraism, Frequency: 1
# Word: dechristianisation, Frequency: 1
# Word: pelikan, Frequency: 1
# Word: chrestiani, Frequency: 1
# Word: fau, Frequency: 1
# Word: godman, Frequency: 1
# Word: wikichristian, Frequency: 1
# Word: superscalar, Frequency: 27
# Word: parallelism, Frequency: 11
# Word: octal, Frequency: 1
# Word: widecharacter, Frequency: 1
# Word: multicharacter, Frequency: 1
# Word: mechatronics, Frequency: 1
# Word: avaya, Frequency: 1
# Word: varian, Frequency: 1
# Word: consortia, Frequency: 1
# Word: naire, Frequency: 1
# Word: actuelle, Frequency: 1
# Word: transistorized, Frequency: 1
# Word: microprogram, Frequency: 3
# Word: isas, Frequency: 3
# Word: rewritable, Frequency: 1
# Word: dissipation, Frequency: 4
# Word: subscalar, Frequency: 6
# Word: artchitectures, Frequency: 1
# Word: xscale, Frequency: 1
# Word: caro, Frequency: 1
# Word: fissipedia, Frequency: 1
# Word: arctoidea, Frequency: 1
# Word: ailurus, Frequency: 2
# Word: musteloidea, Frequency: 1
# Word: superfamilies, Frequency: 2
# Word: caniforms, Frequency: 3
# Word: secondairy, Frequency: 1
# Word: herpestidae, Frequency: 3
# Word: nandinia, Frequency: 1
# Word: miacidae, Frequency: 3
# Word: nimravids, Frequency: 1
# Word: amphicyonids, Frequency: 1
# Word: creodonta, Frequency: 1
# Word: ferae, Frequency: 1
# Word: nandiniidae, Frequency: 1
# Word: viverridae, Frequency: 1
# Word: beardogs, Frequency: 1
# Word: mephitidae, Frequency: 1
# Word: cacique, Frequency: 1
# Word: muisca, Frequency: 1
# Word: chibcha, Frequency: 1
# Word: bastidas, Frequency: 1
# Word: urab, Frequency: 1
# Word: karib, Frequency: 1
# Word: colombians, Frequency: 2
# Word: farc, Frequency: 3
# Word: autodefensas, Frequency: 1
# Word: unidas, Frequency: 1
# Word: pastrana, Frequency: 2
# Word: arango, Frequency: 1
# Word: providencia, Frequency: 2
# Word: ilanos, Frequency: 1
# Word: colombiano, Frequency: 1
# Word: cauca, Frequency: 1
# Word: cristobal, Frequency: 1
# Word: orinoquia, Frequency: 1
# Word: rivality, Frequency: 1
# Word: manizales, Frequency: 2
# Word: importants, Frequency: 1
# Word: estrellas, Frequency: 1
# Word: sucursal, Frequency: 1
# Word: colombias, Frequency: 1
# Word: heroica, Frequency: 1
# Word: querendona, Frequency: 1
# Word: trasnochadora, Frequency: 1
# Word: morena, Frequency: 1
# Word: bucaramanga, Frequency: 1
# Word: abiertas, Frequency: 1
# Word: pasto, Frequency: 1
# Word: sorpresa, Frequency: 1
# Word: milagro, Frequency: 1
# Word: villavicencio, Frequency: 1
# Word: vallenato, Frequency: 2
# Word: revaluation, Frequency: 1
# Word: primarliy, Frequency: 1
# Word: pizzitola, Frequency: 1
# Word: talentless, Frequency: 1
# Word: swanberg, Frequency: 1
# Word: aalberg, Frequency: 1
# Word: roared, Frequency: 1
# Word: goddamned, Frequency: 1
# Word: nasaw, Frequency: 4
# Word: ravecentral, Frequency: 1
# Word: ayylu, Frequency: 1
# Word: hamming, Frequency: 1
# Word: goppa, Frequency: 1
# Word: gallager, Frequency: 1
# Word: cheirogaleoidea, Frequency: 2
# Word: cheirogaleus, Frequency: 8
# Word: adipicaudatus, Frequency: 1
# Word: lehilahytsara, Frequency: 1
# Word: masoala, Frequency: 1
# Word: pariente, Frequency: 1
# Word: parienti, Frequency: 1
# Word: callitrichinae, Frequency: 4
# Word: hapalinae, Frequency: 1
# Word: cebidae, Frequency: 5
# Word: marmosets, Frequency: 3
# Word: callitrichines, Frequency: 2
# Word: saguinus, Frequency: 37
# Word: polyandrous, Frequency: 1
# Word: generalisation, Frequency: 1
# Word: callithrix, Frequency: 53
# Word: jacchus, Frequency: 2
# Word: penicillata, Frequency: 2
# Word: aurita, Frequency: 2
# Word: acariensis, Frequency: 1
# Word: manicore, Frequency: 1
# Word: marcai, Frequency: 2
# Word: humeralifera, Frequency: 2
# Word: saterei, Frequency: 1
# Word: roosmalens, Frequency: 1
# Word: callibella, Frequency: 2
# Word: cebuella, Frequency: 2
# Word: chrysomelas, Frequency: 2
# Word: superagui, Frequency: 2
# Word: graells, Frequency: 2
# Word: melanoleucus, Frequency: 2
# Word: pileatus, Frequency: 2
# Word: labiatus, Frequency: 2
# Word: albifrons, Frequency: 1
# Word: olivaceus, Frequency: 1
# Word: xanthosternos, Frequency: 1
# Word: saimiriinae, Frequency: 1
# Word: saimiri, Frequency: 6
# Word: elasmobranchii, Frequency: 1
# Word: roughsharks, Frequency: 1
# Word: groundsharks, Frequency: 1
# Word: houndsharks, Frequency: 1
# Word: catsharks, Frequency: 1
# Word: lamniformes, Frequency: 2
# Word: megamouth, Frequency: 2
# Word: ovoviviparous, Frequency: 1
# Word: megalodon, Frequency: 2
# Word: carcharodon, Frequency: 1
# Word: holocephali, Frequency: 5
# Word: epigonal, Frequency: 1
# Word: spiracle, Frequency: 1
# Word: placoid, Frequency: 1
# Word: atherion, Frequency: 1
# Word: lapp, Frequency: 1
# Word: laponica, Frequency: 1
# Word: physalis, Frequency: 2
# Word: amno, Frequency: 1
# Word: ramis, Frequency: 1
# Word: glabris, Frequency: 1
# Word: dentoserratis, Frequency: 1
# Word: sensical, Frequency: 1
# Word: matriculation, Frequency: 1
# Word: linnag, Frequency: 1
# Word: avaricious, Frequency: 1
# Word: kalm, Frequency: 1
# Word: solander, Frequency: 1
# Word: hawksbeard, Frequency: 1
# Word: hawkbit, Frequency: 1
# Word: dryander, Frequency: 1
# Word: hasselquist, Frequency: 1
# Word: taxidermy, Frequency: 1
# Word: stratigraphic, Frequency: 1
# Word: seashells, Frequency: 2
# Word: megatheria, Frequency: 1
# Word: detestation, Frequency: 1
# Word: chagas, Frequency: 1
# Word: psychobiological, Frequency: 1
# Word: maer, Frequency: 2
# Word: darwins, Frequency: 1
# Word: cirripedia, Frequency: 3
# Word: forestalled, Frequency: 1
# Word: perpetuation, Frequency: 2
# Word: understatement, Frequency: 1
# Word: paralysing, Frequency: 1
# Word: stigmatised, Frequency: 1
# Word: lepadidae, Frequency: 2
# Word: pedunculated, Frequency: 2
# Word: verrucidae, Frequency: 1
# Word: radick, Frequency: 1
# Word: aboutdarwin, Frequency: 1
# Word: seaborne, Frequency: 1
# Word: cuspate, Frequency: 1
# Word: eustatic, Frequency: 1
# Word: catatonic, Frequency: 9
# Word: hyperactive, Frequency: 3
# Word: beringia, Frequency: 1
# Word: sahul, Frequency: 2
# Word: cosmographie, Frequency: 1
# Word: asthenosphere, Frequency: 1
# Word: ramblers, Frequency: 1
# Word: zandt, Frequency: 1
# Word: maybelle, Frequency: 4
# Word: skaggs, Frequency: 2
# Word: wynonna, Frequency: 2
# Word: acuff, Frequency: 1
# Word: cheatin, Frequency: 1
# Word: faron, Frequency: 1
# Word: baillie, Frequency: 1
# Word: janie, Frequency: 1
# Word: kershaw, Frequency: 1
# Word: krauss, Frequency: 1
# Word: danni, Frequency: 1
# Word: mandrell, Frequency: 1
# Word: lila, Frequency: 1
# Word: lucinda, Frequency: 1
# Word: cornball, Frequency: 1
# Word: hayride, Frequency: 1
# Word: startpage, Frequency: 1
# Word: wherewithal, Frequency: 1
# Word: bankrolling, Frequency: 1
# Word: demilitarization, Frequency: 1
# Word: clamored, Frequency: 1
# Word: wilsonian, Frequency: 1
# Word: unravaged, Frequency: 1
# Word: mahabad, Frequency: 1
# Word: startlingly, Frequency: 1
# Word: isolationists, Frequency: 1
# Word: mastny, Frequency: 1
# Word: lagash, Frequency: 1
# Word: fetha, Frequency: 2
# Word: sarsa, Frequency: 1
# Word: republicae, Frequency: 1
# Word: statuti, Frequency: 1
# Word: comunali, Frequency: 1
# Word: originalism, Frequency: 1
# Word: chaoswiki, Frequency: 1
# Word: snatching, Frequency: 1
# Word: trespasser, Frequency: 2
# Word: countermanded, Frequency: 1
# Word: pluralistic, Frequency: 1
# Word: pleadings, Frequency: 1
# Word: urtheilskraft, Frequency: 1
# Word: zoonomia, Frequency: 1
# Word: evolvability, Frequency: 1
# Word: musicological, Frequency: 1
# Word: internacional, Frequency: 1
# Word: seanaid, Frequency: 1
# Word: artificiality, Frequency: 1
# Word: loglangs, Frequency: 1
# Word: auxlangs, Frequency: 1
# Word: ials, Frequency: 2
# Word: artlangs, Frequency: 3
# Word: armond, Frequency: 1
# Word: conlangers, Frequency: 1
# Word: cratylus, Frequency: 1
# Word: ignota, Frequency: 1
# Word: hildegard, Frequency: 1
# Word: vulgari, Frequency: 1
# Word: lullian, Frequency: 1
# Word: horapollo, Frequency: 1
# Word: polygraphia, Frequency: 1
# Word: dalgarno, Frequency: 1
# Word: charact, Frequency: 1
# Word: faiguet, Frequency: 1
# Word: couturat, Frequency: 1
# Word: leau, Frequency: 1
# Word: pantagruel, Frequency: 1
# Word: conlanger, Frequency: 2
# Word: metalanguage, Frequency: 1
# Word: cabengo, Frequency: 1
# Word: uglossia, Frequency: 1
# Word: kutjarawiki, Frequency: 1
# Word: conlanging, Frequency: 2
# Word: conlangwiki, Frequency: 1
# Word: frathwiki, Frequency: 1
# Word: alphagrip, Frequency: 1
# Word: foldable, Frequency: 1
# Word: altgr, Frequency: 1
# Word: colemak, Frequency: 1
# Word: wearable, Frequency: 1
# Word: quadrans, Frequency: 1
# Word: librae, Frequency: 1
# Word: schickard, Frequency: 1
# Word: reprogrammed, Frequency: 1
# Word: edsac, Frequency: 1
# Word: csirac, Frequency: 1
# Word: sram, Frequency: 1
# Word: arpa, Frequency: 1
# Word: carbonless, Frequency: 1
# Word: minilab, Frequency: 1
# Word: steganographically, Frequency: 1
# Word: interchangably, Frequency: 1
# Word: allotting, Frequency: 1
# Word: internationalism, Frequency: 1
# Word: reassessed, Frequency: 1
# Word: dahrendorf, Frequency: 1
# Word: alinsky, Frequency: 1
# Word: hoxhaism, Frequency: 1
# Word: phane, Frequency: 1
# Word: paczkowski, Frequency: 1
# Word: bartosek, Frequency: 1
# Word: margolin, Frequency: 1
# Word: schwarzbuch, Frequency: 1
# Word: mercantilist, Frequency: 1
# Word: salomone, Frequency: 1
# Word: disclaims, Frequency: 1
# Word: validators, Frequency: 1
# Word: sharer, Frequency: 1
# Word: criminalize, Frequency: 1
# Word: fca, Frequency: 1
# Word: ctea, Frequency: 1
# Word: mpaa, Frequency: 2
# Word: cybersafe, Frequency: 1
# Word: waive, Frequency: 1
# Word: mortgaged, Frequency: 1
# Word: watermarking, Frequency: 1
# Word: valenti, Frequency: 1
# Word: ghosemajumder, Frequency: 1
# Word: babbington, Frequency: 1
# Word: hideaki, Frequency: 1
# Word: infoanarchy, Frequency: 1
# Word: frischmann, Frequency: 1
# Word: moylan, Frequency: 1
# Word: flowchart, Frequency: 2
# Word: catal, Frequency: 9
# Word: valenci, Frequency: 3
# Word: comarques, Frequency: 1
# Word: llitera, Frequency: 1
# Word: cinca, Frequency: 1
# Word: alguer, Frequency: 3
# Word: valenciana, Frequency: 4
# Word: balear, Frequency: 2
# Word: balears, Frequency: 1
# Word: euromosaic, Frequency: 2
# Word: catalanes, Frequency: 1
# Word: languagein, Frequency: 1
# Word: fontanals, Frequency: 1
# Word: consonatic, Frequency: 2
# Word: inchoative, Frequency: 2
# Word: isca, Frequency: 1
# Word: proparoxiton, Frequency: 2
# Word: mirall, Frequency: 1
# Word: llengua, Frequency: 4
# Word: valencians, Frequency: 2
# Word: besal, Frequency: 1
# Word: muntaner, Frequency: 1
# Word: troubadoresque, Frequency: 1
# Word: renaixen, Frequency: 1
# Word: sneaked, Frequency: 1
# Word: plau, Frequency: 1
# Word: aquesta, Frequency: 1
# Word: quant, Frequency: 2
# Word: bany, Frequency: 1
# Word: lavabo, Frequency: 1
# Word: estrangers, Frequency: 1
# Word: ibarz, Frequency: 3
# Word: departament, Frequency: 1
# Word: allioli, Frequency: 1
# Word: diccionari, Frequency: 3
# Word: dacco, Frequency: 1
# Word: vilaweb, Frequency: 1
# Word: overalls, Frequency: 1
# Word: bespectacled, Frequency: 1
# Word: freakish, Frequency: 1
# Word: doberman, Frequency: 1
# Word: scioscia, Frequency: 1
# Word: amadopolis, Frequency: 1
# Word: onassis, Frequency: 1
# Word: performable, Frequency: 1
# Word: notating, Frequency: 1
# Word: drang, Frequency: 1
# Word: emotionalism, Frequency: 1
# Word: italianate, Frequency: 2
# Word: coradin, Frequency: 1
# Word: idiomatically, Frequency: 1
# Word: figuration, Frequency: 2
# Word: examplars, Frequency: 1
# Word: flatward, Frequency: 1
# Word: consonance, Frequency: 1
# Word: guobiao, Frequency: 1
# Word: mojibake, Frequency: 1
# Word: mismap, Frequency: 1
# Word: langauges, Frequency: 1
# Word: erases, Frequency: 1
# Word: interpretable, Frequency: 1
# Word: trigonally, Frequency: 4
# Word: chaoite, Frequency: 1
# Word: nanorods, Frequency: 4
# Word: graphitic, Frequency: 2
# Word: sublimates, Frequency: 1
# Word: charbone, Frequency: 1
# Word: graphites, Frequency: 1
# Word: unnoticeable, Frequency: 1
# Word: heptagons, Frequency: 1
# Word: methanoic, Frequency: 1
# Word: haemoglobin, Frequency: 1
# Word: carbides, Frequency: 2
# Word: abnormaly, Frequency: 1
# Word: lethally, Frequency: 1
# Word: zazula, Frequency: 1
# Word: nonmetals, Frequency: 1
# Word: intead, Frequency: 1
# Word: magnetization, Frequency: 1

# %%
from pyspark.sql import SparkSession

# Create a SparkSession
spark = SparkSession.builder \
    .appName("DataFrame Task") \
    .getOrCreate()

# Load the iris JSON data
iris_df = spark.read.json("/content/iris.json")

# Calculate Pearson Correlation between petalLength and petalWidth
correlation = iris_df.stat.corr("petalLength", "petalWidth")
print("Pearson Correlation between petalLength and petalWidth:", correlation)

# Filter DataFrame to get rows with petalLength >= 1.4 and select required columns
filtered_df = iris_df.filter(iris_df["petalLength"] >= 1.4).select("sepalLength", "sepalWidth", "species")

# Show the filtered DataFrame
filtered_df.show()

# Stop the SparkSession
spark.stop()
# Out:
# Pearson Correlation between petalLength and petalWidth: 0.9626417223780231
# +-----------+----------+-------+
# |sepalLength|sepalWidth|species|
# +-----------+----------+-------+
# |        5.1|       3.5| setosa|
# |        4.9|       3.0| setosa|
# |        4.6|       3.1| setosa|
# |        5.0|       3.6| setosa|
# |        5.4|       3.9| setosa|
# |        4.6|       3.4| setosa|
# |        5.0|       3.4| setosa|
# |        4.4|       2.9| setosa|
# |        4.9|       3.1| setosa|
# |        5.4|       3.7| setosa|
# |        4.8|       3.4| setosa|
# |        4.8|       3.0| setosa|
# |        5.7|       4.4| setosa|
# |        5.1|       3.5| setosa|
# |        5.7|       3.8| setosa|
# |        5.1|       3.8| setosa|
# |        5.4|       3.4| setosa|
# |        5.1|       3.7| setosa|
# |        5.1|       3.3| setosa|
# |        4.8|       3.4| setosa|
# +-----------+----------+-------+
# only showing top 20 rows
